# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv(r'F:\Israel_Stocks.csv')

# %%
dataset
# Out:
#              Date  Closing Price (0.01 NIS)  Change(%)  Opening  Price  \
# 0      22-02-2018                   17550.0       1.15         17440.0
# 1      21-02-2018                   17350.0       3.09         16830.0
# 2      20-02-2018                   16830.0       0.36         16720.0
# 3      19-02-2018                   16770.0       2.51         16340.0
# 4      18-02-2018                   16360.0      -1.09         16380.0
# 5      15-02-2018                   16540.0      -2.93         17040.0
# 6      14-02-2018                   17040.0      -0.76         17210.0
# 7      13-02-2018                   17170.0      -2.11         17450.0
# 8      12-02-2018                   17540.0       2.21         17160.0
# 9      11-02-2018                   17160.0      -0.29         17210.0
# 10     08-02-2018                   17210.0      -1.49         17400.0
# 11     07-02-2018                   17470.0      -0.74         17600.0
# ...

# %%
dataset['Symbol'].nunique()
# Out:
# 35

# %%
dataset=dataset.drop("Symbol",axis=1)

# %%
dataset
# Out:
#              Date  Closing Price (0.01 NIS)  Change(%)  Opening  Price  \
# 0      22-02-2018                   17550.0       1.15         17440.0
# 1      21-02-2018                   17350.0       3.09         16830.0
# 2      20-02-2018                   16830.0       0.36         16720.0
# 3      19-02-2018                   16770.0       2.51         16340.0
# 4      18-02-2018                   16360.0      -1.09         16380.0
# 5      15-02-2018                   16540.0      -2.93         17040.0
# 6      14-02-2018                   17040.0      -0.76         17210.0
# 7      13-02-2018                   17170.0      -2.11         17450.0
# 8      12-02-2018                   17540.0       2.21         17160.0
# 9      11-02-2018                   17160.0      -0.29         17210.0
# 10     08-02-2018                   17210.0      -1.49         17400.0
# 11     07-02-2018                   17470.0      -0.74         17600.0
# ...

# %%
x1=dataset.iloc[0:9999,1:9]

# %%
x2=dataset.iloc[0:9999,10:]

# %%
y=dataset.iloc[0:9999,9]

# %%
y
# Out:
# 0       45119324
# 1       38974624
# 2       31823061
# 3       16290735
# 4       12395932
# 5       62600896
# 6       19221846
# 7       20746492
# 8       17765629
# 9        5906612
# 10      16845905
# 11      18154720
# 12      40833312
# 13      27926485
# 14       6751949
# 15      43695232
# 16      45429019
# 17      20602339
# 18      10094559
# 19       6522844
# 20      42792293
# 21      11304631
# 22      22830645
# 23      23179192
# 24      23404314
# 25      32037450
# 26       8692517
# 27      15432279
# 28      20855401
# 29       4169363
#           ...
# 9969    10397577
# 9970     6753263
# 9971    49107702
# 9972    28690034
# 9973    22794369
# 9974    14799783
# 9975     8347958
# 9976    12953681
# 9977    12465242
# 9978    23821040
# 9979    35114794
# 9980     8587578
# 9981    38682821
# 9982    28006896
# 9983    28316521
# 9984    34114296
# 9985     7418932
# 9986    18796249
# 9987    36855385
# 9988    24875425
# 9989    15926643
# ...

# %%
x2
# Out:
#        Volume  Trans.  Index Adjusted No. of Shares (IANS)
# 0      259345    1484                         1.212728e+08
# 1      227319    1690                         1.212728e+08
# 2      189453     702                         1.212728e+08
# 3       97661    1107                         1.212728e+08
# 4       75962    1001                         1.212728e+08
# 5      375415    1799                         1.212728e+08
# 6      113124    1426                         1.212728e+08
# 7      120346    1288                         1.212728e+08
# 8      101624    1343                         1.212728e+08
# 9       34320     517                         1.212728e+08
# 10      97097     988                         1.212728e+08
# 11     103699    1386                         1.212728e+08
# 12     229941    1308                         1.212728e+08
# 13     154499    1750                         1.212728e+08
# 14      37199     532                         1.212728e+08
# ...

# %%
x=pd.concat([x1,x2], axis=1)

# %%
x
# Out:
#       Closing Price (0.01 NIS)  Change(%)  Opening  Price  Base Price  \
# 0                      17550.0       1.15         17440.0     17350.0
# 1                      17350.0       3.09         16830.0     16830.0
# 2                      16830.0       0.36         16720.0     16770.0
# 3                      16770.0       2.51         16340.0     16360.0
# 4                      16360.0      -1.09         16380.0     16540.0
# 5                      16540.0      -2.93         17040.0     17040.0
# 6                      17040.0      -0.76         17210.0     17170.0
# 7                      17170.0      -2.11         17450.0     17540.0
# 8                      17540.0       2.21         17160.0     17160.0
# 9                      17160.0      -0.29         17210.0     17210.0
# 10                     17210.0      -1.49         17400.0     17470.0
# 11                     17470.0      -0.74         17600.0     17600.0
# ...

# %%
x=pd.concat([x1,x2],axis=1).values

# %%
x
# Out:
# array([[ 1.75500000e+04,  1.15000000e+00,  1.74400000e+04, ...,
#          2.59345000e+05,  1.48400000e+03,  1.21272760e+08],
#        [ 1.73500000e+04,  3.09000000e+00,  1.68300000e+04, ...,
#          2.27319000e+05,  1.69000000e+03,  1.21272760e+08],
#        [ 1.68300000e+04,  3.60000000e-01,  1.67200000e+04, ...,
#          1.89453000e+05,  7.02000000e+02,  1.21272760e+08],
#        ...,
#        [ 9.00200000e+02, -1.29000000e+00,  9.12000000e+02, ...,
#          1.75228800e+06,  9.15000000e+02,  1.16401699e+09],
#        [ 9.12000000e+02,  4.50000000e-01,  9.05000000e+02, ...,
#          2.37296100e+06,  1.32800000e+03,  1.16401699e+09],
#        [ 9.07900000e+02,  1.33000000e+00,  9.04000000e+02, ...,
#          1.04359700e+06,  6.52000000e+02,  1.16401699e+09]])

# %%
x.shape
# Out:
# (9999, 11)

# %%
y=dataset.iloc[0:9999,9].values

# %%
y
# Out:
# array([45119324, 38974624, 31823061, ..., 15874581, 21658043,  9458995],
#       dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state = 0)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
model.add(Dense(input_dim=11,init="random_uniform",output_dim=23)) 
model.add(Dense(init="random_uniform",output_dim=34))
model.add(Dense(init="random_uniform",output_dim=14)) 
model.add(Dense(init="random_uniform",output_dim=4)) 
model.add(Dense(init="random_uniform",output_dim=1)) 
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mse'])
model.fit(x_train,y_train,epochs=100,batch_size=32)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\Shravya Banala\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# C:\Users\Shravya Banala\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=11, units=23, kernel_initializer="random_uniform")`
#   """
# C:\Users\Shravya Banala\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=34, kernel_initializer="random_uniform")`
#
# C:\Users\Shravya Banala\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=14, kernel_initializer="random_uniform")`
#   import sys
# ...

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([[21441596. ],
#        [15576963. ],
#        [ 5597063. ],
#        ...,
#        [22195714. ],
#        [ 5822120. ],
#        [ 4599445.5]], dtype=float32)

# %%
y_test
# Out:
# array([20602580,  4453408,  4376966, ...,  7263483,  4675110, 10639026],
#       dtype=int64)

# %%
y_pred[30]
# Out:
# array([21878650.], dtype=float32)

# %%
y_test[30]
# Out:
# 14312889

# %%
y_pred_s=model.predict(np.array([[16360,-1.09,16380,16540,16480,16200,1.21E+08,19840224,75962,1001,1.21E+08]]))
y_pred_s
# Out:
# array([[22749418.]], dtype=float32)

# %%
y_test_s=model.predict(np.array([[16360,-1.09,16380,16540,16480,16200,1.21E+08,19840224,75962,1001,1.21E+08]]))
y_pred_s
# Out:
# array([[22749418.]], dtype=float32)
